# %% [markdown]
# Consistency Score (Wicketkeeper) = w1 * (Inns / Mat) + w2 * (Dismissed / Mat) + w3 * (Catches taken / Dismissed) + w4 * (Stumpings / Dismissed) + w5 * (Max Dis Inns / Inns) + w6 * (Dis/Inn)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def analyze_and_visualize(df):
    # Select Features for Analysis
    features = ['Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn']
    df_analysis = df[features]
    
    # Replace infinities and NaN with 0
    df_analysis = df_analysis.replace([np.inf, -np.inf], 0)
    df_analysis = df_analysis.fillna(0)
    
    # Correlation Analysis
    correlation_matrix = df_analysis.corr()
    
    # Visualize Correlation Matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
    plt.title('Correlation Matrix of Features')
    plt.show()
    
    return df_analysis

# %%
def calculate_wicketkeeper_formula_components(df):
    """
    Calculates the components of the Wicketkeeper Consistency Score formula.
    
    Consistency Score (Wicketkeeper) = w1 * (Inns / Mat) +
                                      w2 * (Dismissed / Mat) +
                                      w3 * (Catches taken / Dismissed) +
                                      w4 * (Stumpings / Dismissed) +
                                      w5 * (Max Dis Inns / Inns) +
                                      w6 * (Dis/Inn)
    """
    df_components = df.copy()

    # Ensure numeric types for calculations (handle potential NaN from coercion)
    df_components['Inns'] = pd.to_numeric(df_components['Inns'], errors='coerce')
    df_components['Mat'] = pd.to_numeric(df_components['Mat'], errors='coerce')
    df_components['Dismissed'] = pd.to_numeric(df_components['Dismissed'], errors='coerce')
    df_components['Catches taken'] = pd.to_numeric(df_components['Catches taken'], errors='coerce')
    df_components['Stumpings'] = pd.to_numeric(df_components['Stumpings'], errors='coerce')
    df_components['Max Dis Inns'] = pd.to_numeric(df_components['Max Dis Inns'], errors='coerce')
    df_components['Dis/Inn'] = pd.to_numeric(df_components['Dis/Inn'], errors='coerce')

    # Perform calculations, ensure float division and handle potential NaN values
    df_components['Inns_per_Mat'] = df_components['Inns'].astype(float) / df_components['Mat'].astype(float)
    df_components['Dismissed_per_Mat'] = df_components['Dismissed'].astype(float) / df_components['Mat'].astype(float)
    df_components['Catches_per_Dismissed'] = df_components['Catches taken'].astype(float) / df_components['Dismissed'].astype(float)
    df_components['Stumpings_per_Dismissed'] = df_components['Stumpings'].astype(float) / df_components['Dismissed'].astype(float)
    df_components['MaxDisInns_per_Inns'] = df_components['Max Dis Inns'].astype(float) / df_components['Inns'].astype(float)
    df_components['DisInn'] = df_components['Dis/Inn'].astype(float)

    return df_components

# %%
data = pd.read_excel("../../all season cleaned data/wicket_keeperset_ipl.xlsx")
df = data.copy()
print("Data types of your columns before calculation:")
# Out:
# Data types of your columns before calculation:

# %%
numeric_cols = ['Inns', 'Mat', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Use df here

# Verify data types AFTER explicit conversion
print("\nData types of your columns AFTER explicit numeric conversion:")
print(df.dtypes)  # Use df here

# --- Correctly Remove Rows with NaN Values ---
cols_to_check_nan = ['Inns', 'Mat', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn']
print("\nNumber of NaN values BEFORE removing:")
print(df[cols_to_check_nan].isna().sum())  # Check NaN counts in relevant columns before removal

df_cleaned = df.dropna(subset=cols_to_check_nan, how='any')  # Use how='any' to drop row if ANY of these cols is NaN
print("\nNumber of rows BEFORE removing NaNs:", len(df))
print("Number of rows AFTER removing NaNs:", len(df_cleaned))  # Print length of df_cleaned

# Calculate wicketkeeper formula components using the CLEANED data (df_cleaned)
calculations_with_data = calculate_wicketkeeper_formula_components(df_cleaned)  # Pass df_cleaned

# Select the component columns for correlation analysis
component_columns = [
    'Inns_per_Mat',
    'Dismissed_per_Mat',
    'Catches_per_Dismissed',
    'Stumpings_per_Dismissed',
    'MaxDisInns_per_Inns',
    'DisInn'
]

# Calculate the correlation matrix for the components
correlation_matrix = calculations_with_data[component_columns].corr()  # Use calculations_with_data

# Display the correlation matrix
print("\nCorrelation Matrix of Wicketkeeper Consistency Formula Components (after NaN removal):")
print(correlation_matrix)
# Out:
# Data types of your columns AFTER explicit numeric conversion:
# Player                object
# Span                  object
# Mat                    int64
# Inns                   int64
# Dismissed              int64
# Catches taken        float64
# Stumpings            float64
# Max Dis Inns           int64
# Dis/Inn              float64
# Max Dis Inns Type     object
# dtype: object
#
# Number of NaN values BEFORE removing:
# Inns              0
# Mat               0
# Dismissed         0
# Catches taken     3
# Stumpings        17
# Max Dis Inns      0
# Dis/Inn           0
# dtype: int64
#
# Number of rows BEFORE removing NaNs: 59
# Number of rows AFTER removing NaNs: 39
#
# Correlation Matrix of Wicketkeeper Consistency Formula Components (after NaN removal):
#                          Inns_per_Mat  Dismissed_per_Mat  \
# Inns_per_Mat                 1.000000           0.784356
# Dismissed_per_Mat            0.784356           1.000000
# Catches_per_Dismissed       -0.115924          -0.012130
# Stumpings_per_Dismissed      0.115924           0.012130
# MaxDisInns_per_Inns         -0.142830           0.253360
# DisInn                       0.044685           0.622864
#
#                          Catches_per_Dismissed  Stumpings_per_Dismissed  \
# Inns_per_Mat                         -0.115924                 0.115924
# Dismissed_per_Mat                    -0.012130                 0.012130
# Catches_per_Dismissed                 1.000000                -1.000000
# Stumpings_per_Dismissed              -1.000000                 1.000000
# MaxDisInns_per_Inns                  -0.044935                 0.044935
# DisInn                                0.206715                -0.206715
#
#                          MaxDisInns_per_Inns    DisInn
# Inns_per_Mat                       -0.142830  0.044685
# Dismissed_per_Mat                   0.253360  0.622864
# Catches_per_Dismissed              -0.044935  0.206715
# Stumpings_per_Dismissed             0.044935 -0.206715
# MaxDisInns_per_Inns                 1.000000  0.679329
# DisInn                              0.679329  1.000000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_wicketkeeper_consistency_components(df_components):
    features = [
        'Inns_per_Mat',
        'Dismissed_per_Mat',
        'Catches_per_Dismissed',
        'Stumpings_per_Dismissed',
        'MaxDisInns_per_Inns',
        'DisInn'
    ]
    df_analysis = df_components[features].copy()  # Use .copy() to avoid SettingWithCopyWarning

    # Replace infinities and NaN with 0 - Handle potential issues from calculations
    df_analysis = df_analysis.replace([np.inf, -np.inf], 0)
    df_analysis = df_analysis.fillna(0)

    # Correlation Analysis
    correlation_matrix = df_analysis.corr()
    print(correlation_matrix)

    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, fmt=".2f", linewidths=.5)  # Added fmt and linewidths for better readability
    plt.title('Correlation Matrix of Wicketkeeper Consistency Formula Components')
    plt.show()

    return df_analysis

# %%
analyzed_df = analyze_wicketkeeper_consistency_components(calculations_with_data)
# Out:
#                          Inns_per_Mat  Dismissed_per_Mat  \
# Inns_per_Mat                 1.000000           0.784356
# Dismissed_per_Mat            0.784356           1.000000
# Catches_per_Dismissed       -0.115924          -0.012130
# Stumpings_per_Dismissed      0.115924           0.012130
# MaxDisInns_per_Inns         -0.142830           0.253360
# DisInn                       0.044685           0.622864
#
#                          Catches_per_Dismissed  Stumpings_per_Dismissed  \
# Inns_per_Mat                         -0.115924                 0.115924
# Dismissed_per_Mat                    -0.012130                 0.012130
# Catches_per_Dismissed                 1.000000                -1.000000
# Stumpings_per_Dismissed              -1.000000                 1.000000
# MaxDisInns_per_Inns                  -0.044935                 0.044935
# DisInn                                0.206715                -0.206715
#
#                          MaxDisInns_per_Inns    DisInn
# Inns_per_Mat                       -0.142830  0.044685
# Dismissed_per_Mat                   0.253360  0.622864
# Catches_per_Dismissed              -0.044935  0.206715
# Stumpings_per_Dismissed             0.044935 -0.206715
# MaxDisInns_per_Inns                 1.000000  0.679329
# DisInn                              0.679329  1.000000

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.optimize as opt

# Assuming calculations_with_data is your DataFrame after computing the derived metrics,
# and that it includes the following component columns for wicketkeepers:
features = [
    'Inns_per_Mat', 
    'Dismissed_per_Mat', 
    'Catches_per_Dismissed', 
    'Stumpings_per_Dismissed', 
    'MaxDisInns_per_Inns', 
    'DisInn'
]

#########################################
# 1. Principal Component Analysis (PCA)
#########################################

# Prepare the data: fill any NaN and standardize the features
df_pca = calculations_with_data[features].fillna(0)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_pca)

# Run PCA
pca = PCA(n_components=len(features))
principal_components = pca.fit_transform(X_scaled)

# Create a DataFrame of loadings
loadings = pd.DataFrame(pca.components_.T, 
                        columns=[f'PC{i+1}' for i in range(len(features))],
                        index=features)
print("PCA Loadings (each column is a principal component):")
print(loadings)

# You can use the loadings for PC1 (which explains most variance) as guidance for the weights:
pc1_loadings = loadings['PC1']
# Normalize the PC1 loadings (absolute values) to sum to 1:
pca_weights = (np.abs(pc1_loadings) / np.abs(pc1_loadings).sum()).sort_values(ascending=False)
print("\nSuggested Weights from PCA (based on PC1 loadings):")
print(pca_weights)

#########################################
# 2. Analytic Hierarchy Process (AHP)
#########################################

# For AHP, you typically have expert input in the form of a pairwise comparison matrix.
# Here’s an example pairwise comparison matrix for the 6 criteria. 
# (You should adjust these values based on domain expertise.)
pairwise_matrix = np.array([
    [1,   2,   3,   4,   5,   6],
    [1/2, 1,   2,   3,   4,   5],
    [1/3, 1/2, 1,   2,   3,   4],
    [1/4, 1/3, 1/2, 1,   2,   3],
    [1/5, 1/4, 1/3, 1/2, 1,   2],
    [1/6, 1/5, 1/4, 1/3, 1/2, 1]
])

# Calculate the principal eigenvector of the pairwise matrix
eigvals, eigvecs = np.linalg.eig(pairwise_matrix)
max_eigval_index = np.argmax(eigvals.real)
ahp_weights = eigvecs[:, max_eigval_index].real
# Normalize to sum to 1
ahp_weights = ahp_weights / ahp_weights.sum()

# Create a Series with these weights for clarity
ahp_weights_series = pd.Series(ahp_weights, index=features)
print("\nWeights from AHP based on expert pairwise comparisons:")
print(ahp_weights_series)

#########################################
# 3. Optimization-Based Approach
#########################################

# Define a function to calculate the composite consistency score given a set of weights.
def consistency_score(weights, df):
    # weights: array of shape (6,)
    # df: DataFrame containing the metrics in the order of 'features'
    return np.dot(df[features].values, weights)

# Define an objective function.
# In this example, we aim to maximize the variance of the consistency score.
# (Maximizing variance might help differentiate between players.)
def objective(weights, df):
    scores = consistency_score(weights, df)
    # We minimize the negative variance.
    return -np.var(scores)

# Set initial weights (equal distribution)
initial_weights = np.ones(len(features)) / len(features)
# Define bounds if needed (here we constrain weights between 0 and 1)
bounds = [(0, 1)] * len(features)

# Run the optimization
result = opt.minimize(objective, initial_weights, args=(df_pca,), bounds=bounds)
optimized_weights = result.x / result.x.sum()  # Normalize to sum to 1

# Display the optimized weights
optimized_weights_series = pd.Series(optimized_weights, index=features)
print("\nOptimized Weights from the Objective Function (maximizing variance):")
print(optimized_weights_series)
# Out:
# PCA Loadings (each column is a principal component):
#                               PC1       PC2       PC3       PC4       PC5  \
# Inns_per_Mat             0.263183 -0.365472 -0.607513  0.403051 -0.515406
# Dismissed_per_Mat        0.533954 -0.335975 -0.282521 -0.186321  0.698198
# Catches_per_Dismissed    0.284193  0.607795 -0.192038  0.110524  0.026921
# Stumpings_per_Dismissed -0.284193 -0.607795  0.192038 -0.110524 -0.026921
# MaxDisInns_per_Inns      0.379498 -0.111831  0.611101  0.680324  0.084791
# DisInn                   0.583162 -0.047056  0.322347 -0.561749 -0.488096
#
#                                   PC6
# Inns_per_Mat             0.000000e+00
# Dismissed_per_Mat        9.520534e-17
# Catches_per_Dismissed    7.071068e-01
# Stumpings_per_Dismissed  7.071068e-01
# MaxDisInns_per_Inns      2.709451e-16
# DisInn                  -1.536416e-16
#
# Suggested Weights from PCA (based on PC1 loadings):
# DisInn                     0.250480
# Dismissed_per_Mat          0.229344
# MaxDisInns_per_Inns        0.163002
# Catches_per_Dismissed      0.122066
# Stumpings_per_Dismissed    0.122066
# Inns_per_Mat               0.113042
# Name: PC1, dtype: float64
#
# Weights from AHP based on expert pairwise comparisons:
# Inns_per_Mat               0.382497
# Dismissed_per_Mat          0.250402
# Catches_per_Dismissed      0.159580
# Stumpings_per_Dismissed    0.100630
# MaxDisInns_per_Inns        0.064077
# DisInn                     0.042813
# dtype: float64
#
# Optimized Weights from the Objective Function (maximizing variance):
# Inns_per_Mat               0.2
# Dismissed_per_Mat          0.2
# Catches_per_Dismissed      0.2
# Stumpings_per_Dismissed    0.0
# MaxDisInns_per_Inns        0.2
# DisInn                     0.2
# dtype: float64

# %%
import pandas as pd

# Full list of metrics for wicketkeeper
features = ['Inns_per_Mat', 'Dismissed_per_Mat', 'Catches_per_Dismissed', 
            'Stumpings_per_Dismissed', 'MaxDisInns_per_Inns', 'DisInn']

# Original AHP weights from expert pairwise comparisons for all metrics
ahp_weights_series = pd.Series({
    'Inns_per_Mat': 0.382497,
    'Dismissed_per_Mat': 0.250402,
    'Catches_per_Dismissed': 0.159580,
    'Stumpings_per_Dismissed': 0.100630,
    'MaxDisInns_per_Inns': 0.064077,
    'DisInn': 0.042813
})

# Original PCA weights derived from PC1 loadings for all metrics
pca_weights = pd.Series({
    'DisInn': 0.250480,
    'Dismissed_per_Mat': 0.229344,
    'MaxDisInns_per_Inns': 0.163002,
    'Catches_per_Dismissed': 0.122066,
    'Stumpings_per_Dismissed': 0.122066,
    'Inns_per_Mat': 0.113042
})

# Normalize both weight sets so that they sum to 1 (if not already)
ahp_weights_norm = ahp_weights_series / ahp_weights_series.sum()
pca_weights_norm = pca_weights / pca_weights.sum()

# Define a hybrid weighting factor (alpha) between AHP and PCA
alpha = 0.7  # 70% AHP and 30% PCA

# Compute the hybrid weights for all features
hybrid_weights = alpha * ahp_weights_norm + (1 - alpha) * pca_weights_norm

# Now, define boost factors to increase the importance of the selected metrics.
# In this example, we give a boost factor of 2 to the important metrics and leave the others unchanged (factor of 1).
boost_factors = {
    'Inns_per_Mat': 1.0,
    'Dismissed_per_Mat': 1.0,
    'Catches_per_Dismissed': 2.0,
    'Stumpings_per_Dismissed': 2.0,
    'MaxDisInns_per_Inns': 2.0,
    'DisInn': 1.0
}

# Apply the boost factors to the hybrid weights
hybrid_weights_boosted = hybrid_weights.copy()
for metric in features:
    hybrid_weights_boosted[metric] *= boost_factors[metric]

# Normalize again so the boosted weights sum to 1
hybrid_weights_boosted = hybrid_weights_boosted / hybrid_weights_boosted.sum()

print("Hybrid Weights with Emphasis on Selected Wicketkeeper Metrics:")
print(hybrid_weights_boosted)
# Out:
# Hybrid Weights with Emphasis on Selected Wicketkeeper Metrics:
# Catches_per_Dismissed      0.219882
# DisInn                     0.077911
# Dismissed_per_Mat          0.180919
# Inns_per_Mat               0.223595
# MaxDisInns_per_Inns        0.138984
# Stumpings_per_Dismissed    0.158710
# dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'calculations_with_data' is your DataFrame containing the derived metrics
# and 'hybrid_weights_boosted' is your final weight Series with the index corresponding to:
features = ['Inns_per_Mat', 'Dismissed_per_Mat', 'Catches_per_Dismissed', 
            'Stumpings_per_Dismissed', 'MaxDisInns_per_Inns', 'DisInn']

# Define a function to compute the composite consistency score for wicketkeepers
def compute_consistency_score(df, weights):
    # Make sure the DataFrame columns are in the same order as weights.index
    return np.dot(df[weights.index].values, weights.values)

# Compute the base consistency scores with your nominal weights
base_scores = compute_consistency_score(calculations_with_data, hybrid_weights_boosted)

# Set up sensitivity analysis parameters
n_iterations = 100  # Number of perturbation iterations
perturbation_factor = 0.05  # 5% noise
perturbed_scores_list = []

# Generate perturbed weights and compute the corresponding consistency scores
for i in range(n_iterations):
    # Create random noise: normally distributed noise with 0 mean and 5% standard deviation
    noise = np.random.normal(loc=0, scale=perturbation_factor, size=len(hybrid_weights_boosted))
    
    # Apply the noise multiplicatively to each weight
    perturbed_weights = hybrid_weights_boosted * (1 + noise)
    
    # Renormalize to ensure the weights sum to 1
    perturbed_weights = perturbed_weights / perturbed_weights.sum()
    
    # Compute consistency score with perturbed weights
    perturbed_scores = compute_consistency_score(calculations_with_data, perturbed_weights)
    perturbed_scores_list.append(perturbed_scores)

# For each perturbed set, compute the correlation with the base scores
correlations = [np.corrcoef(base_scores, scores)[0, 1] for scores in perturbed_scores_list]

# Also compute the mean relative difference between perturbed scores and base scores
relative_differences = [
    np.mean(np.abs(scores - base_scores)) / np.mean(np.abs(base_scores))
    for scores in perturbed_scores_list
]

# Plot the distribution of correlation coefficients
plt.hist(correlations, bins=20, edgecolor='k')
plt.title("Correlation between Base and Perturbed Wicketkeeper Consistency Scores")
plt.xlabel("Correlation coefficient")
plt.ylabel("Frequency")
plt.show()

# Plot the distribution of relative differences
plt.hist(relative_differences, bins=20, edgecolor='k')
plt.title("Relative Differences in Wicketkeeper Consistency Scores")
plt.xlabel("Relative difference")
plt.ylabel("Frequency")
plt.show()

# Print summary statistics
print("Mean correlation:", np.mean(correlations))
print("Mean relative difference:", np.mean(relative_differences))
# Out:
# Mean correlation: 0.9997338019844305
# Mean relative difference: 0.008082556491881188

# %% [markdown]
# # FINAL CONSISTENCY SCORE CALCULATION
# ### Consistency Score (Wicketkeeper) = 0.223595 * (Inns / Mat) + 0.180919 * (Dismissed / Mat) + 0.219882 * (Catches taken / Dismissed) + 0.158710 * (Stumpings / Dismissed) + 0.138984 * (Max Dis Inns / Inns) + 0.077911 * (Dis/Inn)

# %%
import pandas as pd

# -----------------------------
# 1. Define the metrics and weight sets for wicketkeepers
# -----------------------------
features = ['Inns_per_Mat', 'Dismissed_per_Mat', 'Catches_per_Dismissed', 
            'Stumpings_per_Dismissed', 'MaxDisInns_per_Inns', 'DisIn']

# Original AHP weights from expert pairwise comparisons for all metrics
ahp_weights_series = pd.Series({
    'Inns_per_Mat': 0.382497,
    'Dismissed_per_Mat': 0.250402,
    'Catches_per_Dismissed': 0.159580,
    'Stumpings_per_Dismissed': 0.100630,
    'MaxDisInns_per_Inns': 0.064077,
    'DisIn': 0.042813
})

# Original PCA weights derived from PC1 loadings for all metrics
pca_weights = pd.Series({
    'DisIn': 0.250480,
    'Dismissed_per_Mat': 0.229344,
    'MaxDisInns_per_Inns': 0.163002,
    'Catches_per_Dismissed': 0.122066,
    'Stumpings_per_Dismissed': 0.122066,
    'Inns_per_Mat': 0.113042
})

# Normalize both weight sets so they sum to 1
ahp_weights_norm = ahp_weights_series / ahp_weights_series.sum()
pca_weights_norm = pca_weights / pca_weights.sum()

# Define hybrid weights (70% AHP, 30% PCA)
alpha = 0.7
hybrid_weights = alpha * ahp_weights_norm + (1 - alpha) * pca_weights_norm
hybrid_weights /= hybrid_weights.sum()  # Normalize

# Define boost factors for selected metrics
boost_factors = {
    'Inns_per_Mat': 1.0,
    'Dismissed_per_Mat': 1.0,
    'Catches_per_Dismissed': 2.0,
    'Stumpings_per_Dismissed': 2.0,
    'MaxDisInns_per_Inns': 2.0,
    'DisIn': 1.0
}

# Apply boost factors to hybrid weights and renormalize
hybrid_weights_boosted = hybrid_weights.copy()
for metric in features:
    hybrid_weights_boosted[metric] *= boost_factors[metric]
hybrid_weights_boosted /= hybrid_weights_boosted.sum()

print("Hybrid Weights (Boosted) for Wicketkeeper Metrics:")
print(hybrid_weights_boosted)

# -----------------------------
# 2. Read Data from Excel for Wicketkeepers
# -----------------------------
# Replace with your actual file path and sheet name.
file_path = '/Users/pavanbandaru/Downloads/cricket-squad-selection/all season cleaned data/wicket_keeperset_ipl.xlsx'
df_wk = pd.read_excel(file_path, sheet_name='Sheet1')

# Check the columns available:
print("Columns in wicketkeeper data:", df_wk.columns.tolist())

# -----------------------------
# 3. Convert Relevant Columns to Numeric
# -----------------------------
# Expected columns: 'Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn'
cols_to_convert = ['Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn']
for col in cols_to_convert:
    if col in df_wk.columns:
        df_wk[col] = pd.to_numeric(df_wk[col], errors='coerce')
    else:
        print(f"Warning: Column '{col}' not found in data.")

# Fill NaNs (if any) with 0
df_wk.fillna(0, inplace=True)

# -----------------------------
# 4. Compute Derived Metrics for Wicketkeepers
# -----------------------------
df_wk['Inns_per_Mat'] = df_wk['Inns'] / df_wk['Mat']
df_wk['Dismissed_per_Mat'] = df_wk['Dismissed'] / df_wk['Mat']

# Safe division: if 'Dismissed' equals 0, return 0
df_wk['Catches_per_Dismissed'] = df_wk.apply(
    lambda row: row['Catches taken'] / row['Dismissed'] if row['Dismissed'] != 0 else 0, axis=1)
df_wk['Stumpings_per_Dismissed'] = df_wk.apply(
    lambda row: row['Stumpings'] / row['Dismissed'] if row['Dismissed'] != 0 else 0, axis=1)

df_wk['MaxDisInns_per_Inns'] = df_wk['Max Dis Inns'] / df_wk['Inns']

# For 'DisIn', we assume the column name in the file is 'Dis/Inn'
df_wk['DisIn'] = df_wk['Dis/Inn']

# -----------------------------
# 5. Compute Consistency Score and Ranking for Wicketkeepers
# -----------------------------
def compute_wk_score(row, weights):
    """Compute the composite score for wicketkeepers using the derived metrics."""
    score = 0
    for metric in features:
        score += row[metric] * weights[metric]
    return score

# Compute scores using each weighting scheme
df_wk['Score_AHP'] = df_wk.apply(lambda row: compute_wk_score(row, ahp_weights_norm), axis=1)
df_wk['Score_PCA'] = df_wk.apply(lambda row: compute_wk_score(row, pca_weights_norm), axis=1)
df_wk['Score_Hybrid'] = df_wk.apply(lambda row: compute_wk_score(row, hybrid_weights_boosted), axis=1)

# Rank wicketkeepers (higher score is better; rank 1 is best)
df_wk['Rank_AHP'] = df_wk['Score_AHP'].rank(ascending=False, method='min').astype(int)
df_wk['Rank_PCA'] = df_wk['Score_PCA'].rank(ascending=False, method='min').astype(int)
df_wk['Rank_Hybrid'] = df_wk['Score_Hybrid'].rank(ascending=False, method='min').astype(int)

# -----------------------------
# 6. Display the Rankings
# -----------------------------
cols_to_show = ['Player', 'Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 
                'Max Dis Inns', 'Dis/Inn',
                'Inns_per_Mat', 'Dismissed_per_Mat', 'Catches_per_Dismissed',
                'Stumpings_per_Dismissed', 'MaxDisInns_per_Inns', 'DisIn',
                'Score_AHP', 'Rank_AHP',
                'Score_PCA', 'Rank_PCA',
                'Score_Hybrid', 'Rank_Hybrid']

print("\nWicketkeeper Rankings (AHP-only, PCA-only, and Hybrid):")
print(df_wk[cols_to_show].sort_values(by='Rank_Hybrid'))

# Optionally, save the rankings to an Excel file.
output_file = 'wicketkeeper_rankings.xlsx'
df_wk[cols_to_show].to_excel(output_file, index=False)
print(f"\nRankings saved to {output_file}")
# Out:
# Hybrid Weights (Boosted) for Wicketkeeper Metrics:
# Catches_per_Dismissed      0.219882
# DisIn                      0.077911
# Dismissed_per_Mat          0.180919
# Inns_per_Mat               0.223595
# MaxDisInns_per_Inns        0.138984
# Stumpings_per_Dismissed    0.158710
# dtype: float64
# Columns in wicketkeeper data: ['Player', 'Span', 'Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn', 'Max Dis Inns Type']
#
# Wicketkeeper Rankings (AHP-only, PCA-only, and Hybrid):
#                  Player  Mat  Inns  Dismissed  Catches taken  Stumpings  \
# 46           SS Shaikh     2     1          2            2.0        0.0
# 37          MN van Wyk     5     5          7            7.0        0.0
# 33        Kamran Akmal     6     6          9            5.0        4.0
# 48            DT Patil     2     2          2            2.0        0.0
# 55          BR Sharath     1     1          1            1.0        0.0
# 54          KH Devdhar     1     1          1            0.0        1.0
# 28  Rahmanullah Gurbaz    14    12         15           15.0        0.0
# 34          SP Jackson     9     7          9            7.0        2.0
# 31             N Saini    10     9         11            9.0        2.0
# 21             M Rawat    18    17         18           16.0        2.0
# 27         YV Takawale    16    13         16           12.0        4.0
# 24             PD Salt    21    21         17           17.0        0.0
# 45             SN Khan    50     1          2            2.0        0.0
# 49            AT Carey     3     3          2            2.0        0.0
# 9         AC Gilchrist    80    80         67           51.0       16.0
# 3              RR Pant   111   101         95           72.0       23.0
# 30     KB Arun Karthik    17    16         13           11.0        2.0
# 14           JM Sharma    40    37         28           24.0        4.0
# 0              MS Dhoni  264   257        190          148.0       42.0
# 25           DH Yagnik    25    24         17           12.0        5.0
# 16          SP Goswami    31    28         23           16.0        7.0
# 5            Q de Kock   107    91         81           65.0       16.0
# 8              NV Ojha   113   111         75           65.0       10.0
# 32              PR Shah   16    14         11            8.0        3.0
# 51              U Kaul     5     5          2            2.0        0.0
# 44            L Ronchi     5     4          3            3.0        0.0
# 1           KD Karthik   257   235        174          137.0       37.0
# 2              WP Saha   170   149        113           87.0       26.0
# 26          MV Boucher    31    30         17           14.0        3.0
# 57         B Indrajith     3     3          1            1.0        0.0
# 47             NS Naik     4     2          2            2.0        0.0
# 38           CM Gautam    13    13          7            3.0        4.0
# 6             PA Patel   139   122         81           65.0       16.0
# 20           H Klaasen    35    30         20           13.0        7.0
# 36             MS Wade    15     7          8            7.0        1.0
# 42           KS Bharat    10     8          5            4.0        1.0
# 43           DJ Jacobs     7     6          4            2.0        2.0
# 12       KC Sangakkara    71    51         43           34.0        9.0
# 18            MS Bisla    39    30         22           15.0        7.0
# 15         JM Bairstow    50    28         24           20.0        4.0
# 10            KL Rahul   132    74         63           56.0        7.0
# 11        Ishan Kishan   105    60         49           44.0        5.0
# 41          Anuj Rawat    24     6          6            6.0        0.0
# 40       Abishek Porel    18     5          6            6.0        0.0
# 7            SV Samson   168   108         75           59.0       16.0
# 58         AG Paunikar     5     4          1            1.0        0.0
# 53    Anmolpreet Singh     9     1          1            1.0        0.0
# 50        Vishnu Vinod     6     4          2            0.0        2.0
# 4           RV Uthappa   205   114         90           58.0       32.0
# 35         SW Billings    30     7          8            7.0        1.0
# 23            N Pooran    76    31         18           14.0        4.0
# 17           KM Jadhav    95    33         23           16.0        7.0
# 19          JC Buttler   107    30         21           20.0        1.0
# 22         BB McCullum   109    18         18           12.0        6.0
# 13      AB de Villiers   184    52         36           28.0        8.0
# 39             AP Tare    35    15          7            2.0        5.0
# 29           AT Rayudu   204    20         15           13.0        2.0
# 52   Prabhsimran Singh    34     5          2            2.0        0.0
# 56     Gurkeerat Singh    41     3          1            0.0        1.0
#
#     Max Dis Inns  Dis/Inn  Inns_per_Mat  Dismissed_per_Mat  \
# 46             2    2.000      0.500000           1.000000
# 37             4    1.400      1.000000           1.400000
# 33             2    1.500      1.000000           1.500000
# 48             2    1.000      1.000000           1.000000
# 55             1    1.000      1.000000           1.000000
# 54             1    1.000      1.000000           1.000000
# 28             4    1.250      0.857143           1.071429
# 34             4    1.285      0.777778           1.000000
# 31             2    1.222      0.900000           1.100000
# 21             3    1.058      0.944444           1.000000
# 27             4    1.230      0.812500           1.000000
# 24             3    0.809      1.000000           0.809524
# 45             2    2.000      0.020000           0.040000
# 49             1    0.666      1.000000           0.666667
# 9              4    0.837      1.000000           0.837500
# 3              4    0.940      0.909910           0.855856
# 30             2    0.812      0.941176           0.764706
# 14             3    0.756      0.925000           0.700000
# 0              4    0.739      0.973485           0.719697
# 25             3    0.708      0.960000           0.680000
# 16             2    0.821      0.903226           0.741935
# 5              4    0.890      0.850467           0.757009
# 8              4    0.675      0.982301           0.663717
# 32             2    0.785      0.875000           0.687500
# 51             2    0.400      1.000000           0.400000
# 44             1    0.750      0.800000           0.600000
# 1              4    0.740      0.914397           0.677043
# 2              4    0.758      0.876471           0.664706
# 26             2    0.566      0.967742           0.548387
# 57             1    0.333      1.000000           0.333333
# 47             1    1.000      0.500000           0.500000
# 38             2    0.538      1.000000           0.538462
# 6              4    0.663      0.877698           0.582734
# 20             4    0.666      0.857143           0.571429
# 36             3    1.142      0.466667           0.533333
# 42             2    0.625      0.800000           0.500000
# 43             1    0.666      0.857143           0.571429
# 12             5    0.843      0.718310           0.605634
# 18             3    0.733      0.769231           0.564103
# 15             3    0.857      0.560000           0.480000
# 10             3    0.851      0.560606           0.477273
# 11             3    0.816      0.571429           0.466667
# 41             4    1.000      0.250000           0.250000
# 40             2    1.200      0.277778           0.333333
# 7              4    0.694      0.642857           0.446429
# 58             1    0.250      0.800000           0.200000
# 53             1    1.000      0.111111           0.111111
# 50             2    0.500      0.666667           0.333333
# 4              4    0.789      0.556098           0.439024
# 35             3    1.142      0.233333           0.266667
# 23             3    0.580      0.407895           0.236842
# 17             2    0.696      0.347368           0.242105
# 19             2    0.700      0.280374           0.196262
# 22             4    1.000      0.165138           0.165138
# 13             3    0.692      0.282609           0.195652
# 39             2    0.466      0.428571           0.200000
# 29             3    0.750      0.098039           0.073529
# 52             1    0.400      0.147059           0.058824
# 56             1    0.333      0.073171           0.024390
#
#     Catches_per_Dismissed  Stumpings_per_Dismissed  MaxDisInns_per_Inns  \
# 46               1.000000                 0.000000             2.000000
# 37               1.000000                 0.000000             0.800000
# 33               0.555556                 0.444444             0.333333
# 48               1.000000                 0.000000             1.000000
# 55               1.000000                 0.000000             1.000000
# 54               0.000000                 1.000000             1.000000
# 28               1.000000                 0.000000             0.333333
# 34               0.777778                 0.222222             0.571429
# 31               0.818182                 0.181818             0.222222
# 21               0.888889                 0.111111             0.176471
# 27               0.750000                 0.250000             0.307692
# 24               1.000000                 0.000000             0.142857
# 45               1.000000                 0.000000             2.000000
# 49               1.000000                 0.000000             0.333333
# 9                0.761194                 0.238806             0.050000
# 3                0.757895                 0.242105             0.039604
# 30               0.846154                 0.153846             0.125000
# 14               0.857143                 0.142857             0.081081
# 0                0.778947                 0.221053             0.015564
# 25               0.705882                 0.294118             0.125000
# 16               0.695652                 0.304348             0.071429
# 5                0.802469                 0.197531             0.043956
# 8                0.866667                 0.133333             0.036036
# 32               0.727273                 0.272727             0.142857
# 51               1.000000                 0.000000             0.400000
# 44               1.000000                 0.000000             0.250000
# 1                0.787356                 0.212644             0.017021
# 2                0.769912                 0.230088             0.026846
# 26               0.823529                 0.176471             0.066667
# 57               1.000000                 0.000000             0.333333
# 47               1.000000                 0.000000             0.500000
# 38               0.428571                 0.571429             0.153846
# 6                0.802469                 0.197531             0.032787
# 20               0.650000                 0.350000             0.133333
# 36               0.875000                 0.125000             0.428571
# 42               0.800000                 0.200000             0.250000
# 43               0.500000                 0.500000             0.166667
# 12               0.790698                 0.209302             0.098039
# 18               0.681818                 0.318182             0.100000
# 15               0.833333                 0.166667             0.107143
# 10               0.888889                 0.111111             0.040541
# 11               0.897959                 0.102041             0.050000
# 41               1.000000                 0.000000             0.666667
# 40               1.000000                 0.000000             0.400000
# 7                0.786667                 0.213333             0.037037
# 58               1.000000                 0.000000             0.250000
# 53               1.000000                 0.000000             1.000000
# 50               0.000000                 1.000000             0.500000
# 4                0.644444                 0.355556             0.035088
# 35               0.875000                 0.125000             0.428571
# 23               0.777778                 0.222222             0.096774
# 17               0.695652                 0.304348             0.060606
# 19               0.952381                 0.047619             0.066667
# 22               0.666667                 0.333333             0.222222
# 13               0.777778                 0.222222             0.057692
# 39               0.285714                 0.714286             0.133333
# 29               0.866667                 0.133333             0.150000
# 52               1.000000                 0.000000             0.200000
# 56               0.000000                 1.000000             0.333333
#
#     DisIn  Score_AHP  Rank_AHP  Score_PCA  Rank_PCA  Score_Hybrid  Rank_Hybrid
# 46  2.000   0.815011         9   1.234895         1      0.946388            1
# 37  1.400   1.003841         1   1.037263         2      0.917025            2
# 33  1.500   0.977059         2   1.009178         3      0.850862            3
# 48  1.000   0.899370         3   0.877934         5      0.841290            4
# 55  1.000   0.899370         3   0.877934         5      0.841290            4
# 54  1.000   0.840420         5   0.877934         5      0.780118            6
# 28  1.250   0.830599         7   0.832119         9      0.749093            7
# 34  1.285   0.786011        11   0.854342         8      0.740649            8
# 31  1.222   0.835109         6   0.818391        10      0.735098            9
# 21  1.058   0.821284         8   0.751945        12      0.712133           10
# 27  1.230   0.778400        12   0.801501        11      0.705773           11
# 24  0.809   0.788574        10   0.646692        15      0.672819           12
# 45  2.000   0.391026        49   0.960465         4      0.665381           13
# 49  0.666   0.758885        14   0.609158        21      0.662306           14
# 9   0.837   0.776750        13   0.644985        16      0.652548           15
# 3   0.940   0.750436        15   0.663116        13      0.642104           16
# 30  0.812   0.744766        16   0.627604        17      0.639899           17
# 14  0.756   0.717812        20   0.589750        24      0.614781           18
# 0   0.739   0.731754        17   0.584811        25      0.613972           19
# 25  0.708   0.718034        19   0.584255        26      0.612100           20
# 16  0.821   0.712629        21   0.611614        20      0.611343           21
# 5   0.890   0.703714        22   0.621912        19      0.610366           22
# 8   0.675   0.724852        18   0.560275        34      0.609040           23
# 32  0.785   0.693102        24   0.598565        22      0.604241           24
# 51  0.400   0.684994        26   0.492238        45      0.602602           25
# 44  0.750   0.663948        29   0.578716        27      0.600488           26
# 1   0.740   0.699105        23   0.568837        30      0.593838           27
# 2   0.758   0.681880        27   0.567830        31      0.584826           28
# 26  0.566   0.685157        25   0.509869        43      0.578045           29
# 57  0.333   0.661161        30   0.449300        50      0.576055           30
# 47  1.000   0.550882        37   0.625240        18      0.569542           31
# 38  0.538   0.676115        28   0.518436        41      0.569237           32
# 6   0.663   0.660057        31   0.526342        39      0.565686           33
# 20  0.666   0.646947        32   0.538566        36      0.563926           34
# 36  1.142   0.540612        39   0.653042        14      0.561609           35
# 42  0.625   0.621767        34   0.524472        40      0.560423           36
# 43  0.666   0.640240        33   0.544000        35      0.559383           37
# 12  0.843   0.616019        35   0.569299        29      0.556564           38
# 18  0.733   0.614094        36   0.538297        37      0.545478           39
# 15  0.857   0.527703        41   0.527581        38      0.503401           40
# 10  0.851   0.526002        43   0.514664        42      0.496718           41
# 11  0.816   0.527128        42   0.506230        44      0.496362           42
# 41  1.000   0.403336        47   0.566810        32      0.491577           43
# 40  1.200   0.426303        46   0.595691        23      0.491385           44
# 7   0.694   0.536768        40   0.476992        48      0.490556           45
# 58  0.250   0.542381        38   0.361739        56      0.489165           46
# 53  1.000   0.336792        55   0.573591        28      0.481723           47
# 50  0.500   0.492541        45   0.480616        47      0.476527           48
# 4   0.789   0.497287        44   0.488964        46      0.468248           49
# 35  1.142   0.384589        50   0.565507        33      0.461192           50
# 23  0.580   0.392837        48   0.383546        53      0.398979           51
# 17  0.696   0.368811        51   0.401072        51      0.385385           52
# 19  0.700   0.347401        53   0.384974        52      0.378970           53
# 22  1.000   0.301498        56   0.465309        49      0.375088           54
# 13  0.692   0.336892        54   0.381620        54      0.366808           55
# 39  0.466   0.359975        52   0.354839        57      0.363035           56
# 29  0.750   0.249353        58   0.362322        55      0.326230           57
# 52  0.400   0.260500        57   0.284973        58      0.322367           58
# 56  0.333   0.170341        59   0.273675        59      0.251755           59
#
# Rankings saved to wicketkeeper_rankings.xlsx

# %%
import pandas as pd

# -----------------------------
# 1. Define the derived metric names and weight sets for wicketkeepers
# -----------------------------
# Derived metrics (features):
features = ['Inns_per_Mat', 'Dismissed_per_Mat', 'Catches_per_Dismissed', 
            'Stumpings_per_Dismissed', 'MaxDisInns_per_Inns', 'DisIn']

# Original AHP weights from expert pairwise comparisons for wicketkeeper metrics (example values)
ahp_weights_series = pd.Series({
    'Inns_per_Mat': 0.382497,
    'Dismissed_per_Mat': 0.250402,
    'Catches_per_Dismissed': 0.159580,
    'Stumpings_per_Dismissed': 0.100630,
    'MaxDisInns_per_Inns': 0.064077,
    'DisIn': 0.042813
})

# Original PCA weights derived from PC1 loadings for wicketkeeper metrics (example values)
pca_weights = pd.Series({
    'DisIn': 0.250480,
    'Dismissed_per_Mat': 0.229344,
    'MaxDisInns_per_Inns': 0.163002,
    'Catches_per_Dismissed': 0.122066,
    'Stumpings_per_Dismissed': 0.122066,
    'Inns_per_Mat': 0.113042
})

# Normalize weights so that they sum to 1 (if not already)
ahp_weights_norm = ahp_weights_series / ahp_weights_series.sum()
pca_weights_norm = pca_weights / pca_weights.sum()

# Hybrid weights: 70% AHP, 30% PCA
alpha = 0.7
hybrid_weights = alpha * ahp_weights_norm + (1 - alpha) * pca_weights_norm
hybrid_weights /= hybrid_weights.sum()  # Normalize

# -----------------------------
# 2. Read Data from Excel for Wicketkeepers
# -----------------------------
# Replace the file path and sheet name with your actual file path/sheet.
file_path = '/Users/pavanbandaru/Downloads/cricket-squad-selection/all season cleaned data/wicket_keeperset_ipl.xlsx'
df_wk = pd.read_excel(file_path, sheet_name='Sheet1')

# Expected columns in your Excel file (adjust names if needed):
# 'Player', 'Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn'
print("Columns in wicketkeeper data:", df_wk.columns.tolist())

# -----------------------------
# 3. Convert Relevant Columns to Numeric
# -----------------------------
# List of columns to convert (update as needed)
cols_to_convert = ['Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn']
for col in cols_to_convert:
    if col in df_wk.columns:
        df_wk[col] = pd.to_numeric(df_wk[col], errors='coerce')
    else:
        print(f"Warning: Column '{col}' not found in data.")

# Fill any NaNs with 0
df_wk.fillna(0, inplace=True)

# -----------------------------
# 4. Compute Derived Metrics for Wicketkeepers
# -----------------------------
df_wk['Inns_per_Mat'] = df_wk['Inns'] / df_wk['Mat']
df_wk['Dismissed_per_Mat'] = df_wk['Dismissed']

# Use safe division for ratios: if Dismissed is 0, return 0.
df_wk['Catches_per_Dismissed'] = df_wk.apply(
    lambda row: row['Catches taken'] / row['Dismissed'] if row['Dismissed'] != 0 else 0, axis=1)
df_wk['Stumpings_per_Dismissed'] = df_wk.apply(
    lambda row: row['Stumpings'] / row['Dismissed'] if row['Dismissed'] != 0 else 0, axis=1)

df_wk['MaxDisInns_per_Inns'] = df_wk['Max Dis Inns'] 
df_wk['DisIn'] = df_wk['Dis/Inn']  # Assuming 'Dis/Inn' is already computed

# -----------------------------
# 5. Define Function to Compute Consistency Score and Rank
# -----------------------------
def compute_wk_score(row, weights):
    """
    Computes the composite consistency score for wicketkeepers as:
      Score = w1*(Inns/Mat) + w2*(Dismissed/Mat) + w3*(Catches taken/Dismissed)
            + w4*(Stumpings/Dismissed) + w5*(Max Dis Inns/Inns) + w6*(Dis/Inn)
    """
    score = 0
    for metric in features:
        score += row[metric] * weights[metric]
    return score

# Compute scores for each weighting method
df_wk['Score_AHP'] = df_wk.apply(lambda row: compute_wk_score(row, ahp_weights_norm), axis=1)
df_wk['Score_PCA'] = df_wk.apply(lambda row: compute_wk_score(row, pca_weights_norm), axis=1)
df_wk['Score_Hybrid'] = df_wk.apply(lambda row: compute_wk_score(row, hybrid_weights), axis=1)

# Rank players: higher score gets a better rank (1 is best)
df_wk['Rank_AHP'] = df_wk['Score_AHP'].rank(ascending=False, method='min').astype(int)
df_wk['Rank_PCA'] = df_wk['Score_PCA'].rank(ascending=False, method='min').astype(int)
df_wk['Rank_Hybrid'] = df_wk['Score_Hybrid'].rank(ascending=False, method='min').astype(int)

# -----------------------------
# 6. Display the Rankings
# -----------------------------
cols_to_display = ['Player', 'Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 
                     'Max Dis Inns', 'Dis/Inn',
                     'Inns_per_Mat', 'Dismissed_per_Mat', 'Catches_per_Dismissed',
                     'Stumpings_per_Dismissed', 'MaxDisInns_per_Inns', 'DisIn',
                     'Score_AHP', 'Rank_AHP',
                     'Score_PCA', 'Rank_PCA',
                     'Score_Hybrid', 'Rank_Hybrid']

ranking_output = df_wk[cols_to_display].sort_values(by='Rank_Hybrid')
print("Wicketkeeper Rankings using PCA-only, AHP-only, and Hybrid weights:")
print(ranking_output.head(10))

# Optionally, save the rankings to an Excel file
ranking_output.to_excel('wicketkeeper_rankings.xlsx', index=False)
print("\nRankings saved to 'wicketkeeper_rankings.xlsx'")
# Out:
# Columns in wicketkeeper data: ['Player', 'Span', 'Mat', 'Inns', 'Dismissed', 'Catches taken', 'Stumpings', 'Max Dis Inns', 'Dis/Inn', 'Max Dis Inns Type']
# Wicketkeeper Rankings using PCA-only, AHP-only, and Hybrid weights:
#           Player  Mat  Inns  Dismissed  Catches taken  Stumpings  \
# 0       MS Dhoni  264   257        190          148.0       42.0
# 1    KD Karthik   257   235        174          137.0       37.0
# 2       WP Saha   170   149        113           87.0       26.0
# 3       RR Pant   111   101         95           72.0       23.0
# 4    RV Uthappa   205   114         90           58.0       32.0
# 5     Q de Kock   107    91         81           65.0       16.0
# 6      PA Patel   139   122         81           65.0       16.0
# 8       NV Ojha   113   111         75           65.0       10.0
# 7     SV Samson   168   108         75           59.0       16.0
# 9  AC Gilchrist    80    80         67           51.0       16.0
#
#    Max Dis Inns  Dis/Inn  Inns_per_Mat  Dismissed_per_Mat  \
# 0             4    0.739      0.973485                190
# 1             4    0.740      0.914397                174
# 2             4    0.758      0.876471                113
# 3             4    0.940      0.909910                 95
# 4             4    0.789      0.556098                 90
# 5             4    0.890      0.850467                 81
# 6             4    0.663      0.877698                 81
# 8             4    0.675      0.982301                 75
# 7             4    0.694      0.642857                 75
# 9             4    0.837      1.000000                 67
#
#    Catches_per_Dismissed  Stumpings_per_Dismissed  MaxDisInns_per_Inns  DisIn  \
# 0               0.778947                 0.221053                    4  0.739
# 1               0.787356                 0.212644                    4  0.740
# 2               0.769912                 0.230088                    4  0.758
# 3               0.757895                 0.242105                    4  0.940
# 4               0.644444                 0.355556                    4  0.789
# 5               0.802469                 0.197531                    4  0.890
# 6               0.802469                 0.197531                    4  0.663
# 8               0.866667                 0.133333                    4  0.675
# 7               0.786667                 0.213333                    4  0.694
# 9               0.761194                 0.238806                    4  0.837
#
#    Score_AHP  Rank_AHP  Score_PCA  Rank_PCA  Score_Hybrid  Rank_Hybrid
# 0  48.383279         1  44.644583         1     47.261670            1
# 1  44.354781         2  40.968650         2     43.338942            2
# 2  29.065479         3  26.978888         3     28.439502            3
# 3  24.578113         4  22.900063         4     24.074698            4
# 4  23.177616         5  21.675525         5     22.726989            5
# 5  21.050231         7  19.670004         6     20.636163            6
# 6  21.050928         6  19.616223         7     20.620517            7
# 8  19.592824         8  18.254989         8     19.191473            8
# 7  19.459085         9  18.221377         9     19.087772            9
# 9  17.597093        10  16.462816        10     17.256810           10
#
# Rankings saved to 'wicketkeeper_rankings.xlsx'
